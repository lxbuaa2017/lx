# %% [markdown]
# 拟用LTP语义图

# %%
# !conda install python-graphviz -y
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/LAB/magh/.conda/envs/lx
#
#   added / updated specs:
#     - python-graphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cffi-1.14.0                |   py36h2e261b9_0         225 KB
#     fribidi-1.0.10             |       h7b6447c_0         115 KB
#     glib-2.63.1                |       h5a9c865_0         3.4 MB
#     graphite2-1.3.14           |       h23475e2_0         102 KB
#     graphviz-2.40.1            |       h21bd128_2         6.9 MB
#     libffi-3.2.1               |    hf484d3e_1007          52 KB
#     lz4-c-1.9.3                |       h2531618_0         216 KB
#     pixman-0.40.0              |       h7b6447c_0         628 KB
#     python-3.6.10              |       hcf32534_1        33.9 MB
#     python-graphviz-0.16       |     pyhd3eb1b0_1          20 KB
# ...

# %%
# !ls
# Out:
# DataSet     Generate_Graph_Data.ipynb  Graph_Classification.ipynb
# Digraph.gv  graph		       PYGDemo.ipynb

# %%
from graphviz import Digraph
dot = Digraph(comment='test')
dot.node('A', 'King Arthur')
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')
dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='false',label='rel')
# dot.render('graph/test.gv',view=True)
dot

# %%
import json
train_set=[]
with open('DataSet/train_CED.json') as f:
    data=f.read()
    train_set=json.loads(data)
len(train_set),train_set[0]
# Out:
# (2711,
#  {'text': '把家里的油放到冰箱2个小时，如果出现白色的泡沫，那就是地沟油.或者用最简单方法:在炒菜时放一颗剥皮的大蒜，蒜对黄曲霉素最敏感。如果蒜变红色，就是地沟油。油良好的话，蒜是白色的。 为了自己，朋友，亲人，以防万一，转一下吧！！！有人为报道此事，已付出生命！！！',
#   'label': 1})
